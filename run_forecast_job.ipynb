# %%
# run_forecast_job.py

from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential
from azure.ai.ml.entities import CommandJob

ml_client = MLClient(
    DefaultAzureCredential(),
    subscription_id="7db2b459-a548-48f4-a984-f75f5bae5548",  # Replace below
    resource_group_name="venumadhuri.y-rg",
    workspace_name="energy-ml-ws"
)

job = CommandJob(
    code="./",  # directory where energy_forecast_arima.py is located
    command="python energy_forecast_arima.py",
    environment="arima-env@latest",
    compute="arima-instance",  # name of your compute
    experiment_name="energy-forecast-arima"
)

ml_client.jobs.create_or_update(job)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # run_forecast_job.py
# ----> 3 from azure.ai.ml import MLClient
#       4 from azure.identity import DefaultAzureCredential
#       5 from azure.ai.ml.entities import CommandJob
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\azure\ai\ml\__init__.py:13
#      10 # from .entities._builders.parallel_func import parallel
#      11 from azure.ai.ml.entities._inputs_outputs import Input, Output
# ---> 13 from ._ml_client import MLClient
#      14 from ._utils._logger_utils import initialize_logger_info
#      15 from ._version import VERSION
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\azure\ai\ml\_ml_client.py:79
#      77 from azure.ai.ml.entities._workspace._ai_workspaces.capability_host import CapabilityHost
#      78 from azure.ai.ml.exceptions import ErrorCategory, ErrorTarget, ValidationException
# ---> 79 from azure.ai.ml.operations import (
#      80     AzureOpenAIDeploymentOperations,
#      81     BatchDeploymentOperations,
#      82     BatchEndpointOperations,
#      83     ComponentOperations,
#      84     ComputeOperations,
#      85     DataOperations,
#      86     DatastoreOperations,
#      87     EnvironmentOperations,
#      88     EvaluatorOperations,
#      89     IndexOperations,
#      90     JobOperations,
#      91     MarketplaceSubscriptionOperations,
#      92     ModelOperations,
#      93     OnlineDeploymentOperations,
#      94     OnlineEndpointOperations,
#      95     RegistryOperations,
#      96     ServerlessEndpointOperations,
#      97     WorkspaceConnectionsOperations,
#      98     WorkspaceOperations,
#      99 )
#     100 from azure.ai.ml.operations._capability_hosts_operations import CapabilityHostsOperations
#     101 from azure.ai.ml.operations._code_operations import CodeOperations
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\azure\ai\ml\operations\__init__.py:17
#      15 from ._component_operations import ComponentOperations
#      16 from ._compute_operations import ComputeOperations
# ---> 17 from ._data_operations import DataOperations
#      18 from ._datastore_operations import DatastoreOperations
#      19 from ._environment_operations import EnvironmentOperations
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\azure\ai\ml\operations\_data_operations.py:46
#      36 from azure.ai.ml._telemetry import ActivityType, monitor_with_activity
#      37 from azure.ai.ml._utils._asset_utils import (
#      38     _archive_or_restore,
#      39     _check_or_modify_auto_delete_setting,
#    (...)
#      44     _validate_workspace_managed_datastore,
#      45 )
# ---> 46 from azure.ai.ml._utils._data_utils import (
#      47     download_mltable_metadata_schema,
#      48     read_local_mltable_metadata_contents,
#      49     read_remote_mltable_metadata_contents,
#      50     validate_mltable_metadata,
#      51 )
#      52 from azure.ai.ml._utils._experimental import experimental
#      53 from azure.ai.ml._utils._http_utils import HttpPipeline
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\azure\ai\ml\_utils\_data_utils.py:14
#      11 from urllib.parse import urljoin, urlparse
#      13 import yaml
# ---> 14 from jsonschema import Draft7Validator, ValidationError
#      15 from jsonschema.exceptions import best_match
#      17 from azure.ai.ml._artifacts._artifact_utilities import get_datastore_info, get_storage_client
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\jsonschema\__init__.py:13
#       1 """
#       2 An implementation of JSON Schema for Python.
#       3
#    (...)
#       9 for you.
#      10 """
#      11 import warnings
# ---> 13 from jsonschema._format import FormatChecker
#      14 from jsonschema._types import TypeChecker
#      15 from jsonschema.exceptions import SchemaError, ValidationError
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\jsonschema\_format.py:11
#       8 import typing
#       9 import warnings
# ---> 11 from jsonschema.exceptions import FormatError
#      13 _FormatCheckCallable = typing.Callable[[object], bool]
#      14 #: A format checker callable.
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\jsonschema\exceptions.py:13
#      10 import heapq
#      11 import warnings
# ---> 13 from attrs import define
#      14 from referencing.exceptions import Unresolvable as _Unresolvable
#      16 from jsonschema import _utils
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\attrs\__init__.py:27
#       3 from attr import (
#       4     NOTHING,
#       5     Attribute,
#    (...)
#      23     validate,
#      24 )
#      25 from attr._next_gen import asdict, astuple
# ---> 27 from . import converters, exceptions, filters, setters, validators
#      30 __all__ = [
#      31     "NOTHING",
#      32     "Attribute",
#    (...)
#      66     "validators",
#      67 ]
#      69 __getattr__ = _make_getattr(__name__)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:846, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:941, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1039, in get_data(self, path)
#
# KeyboardInterrupt:
